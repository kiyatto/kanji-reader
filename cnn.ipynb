# %%
import numpy as np
from PIL import Image

import torch
import torch.nn as nn
import torch.optim as optim

import torchvision
import torchvision.transforms as transforms

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
# run once to get 64 x 64 imgs
# images = np.load("./data/kanji_images.npy", mmap_mode="r")
# resized = np.empty((len(images), 64, 64), dtype=np.uint8)

# for i in range(len(images)):
#     img = Image.fromarray(images[i]).resize((64, 64), Image.BILINEAR)
#     resized[i] = np.array(img)

# np.save("kanji_images_64.npy", resized)

# %%
from torch.utils.data import Dataset, DataLoader

# batch & normalizing

class KanjiDataset(Dataset):
    def __init__(self, image_file, label_file, indices):
        self.images = np.load(image_file)
        self.labels = np.load(label_file)
        self.indices = indices

    def __len__(self):
        return len(self.indices)

    def __getitem__(self, idx):
        real_idx = self.indices[idx]
        image = torch.from_numpy(self.images[real_idx].copy()).float().div(255.0).unsqueeze(0)
        label = torch.tensor(self.labels[real_idx]).long()

        return image, label

# %%
from sklearn.model_selection import train_test_split

# train test split
class_list = np.load("./data/class_list.npy")
y = np.load("./data/kanji_labels.npy")

indices = np.arange(len(y))
train_idx, temp_idx = train_test_split(indices, test_size=0.2, stratify=y, random_state=42)
val_idx, test_idx = train_test_split(temp_idx, test_size=0.5, stratify=y[temp_idx], random_state=42)

train_data = KanjiDataset("kanji_images_64.npy", "./data/kanji_labels.npy", train_idx)
val_data = KanjiDataset("kanji_images_64.npy", "./data/kanji_labels.npy", val_idx)
test_data = KanjiDataset( "kanji_images_64.npy", "./data/kanji_labels.npy", test_idx)

# %%
# image, label = train_data[0]
# print(image.size())
# print(len(class_list))

# %%
# define CNN network
class NeuralNet(nn.Module):

    # blocks = 3x3 conv, 

    def __init__(self, num_classes=3036, input_size=64):
        super().__init__()

        self.features = nn.Sequential(
            # block 1
            nn.Conv2d(1, 32, 3, padding=1), nn.BatchNorm2d(32), nn.ReLU(),
            nn.Conv2d(32, 32, 3, padding=1), nn.BatchNorm2d(32), nn.ReLU(),
            nn.MaxPool2d(2, 2),

            # block 2
            nn.Conv2d(32, 64, 3, padding=1), nn.BatchNorm2d(64), nn.ReLU(),
            nn.Conv2d(64, 64, 3, padding=1), nn.BatchNorm2d(64), nn.ReLU(),
            nn.MaxPool2d(2, 2),

            # block 3
            nn.Conv2d(64, 128, 3, padding=1), nn.BatchNorm2d(128), nn.ReLU(),
            nn.Conv2d(128, 128, 3, padding=1), nn.BatchNorm2d(128), nn.ReLU(),
            nn.MaxPool2d(2, 2),
        )

        # infer flatten size
        with torch.no_grad():
            dummy = torch.zeros(1, 1, input_size, input_size)
            flat_size = self.features(dummy).flatten(1).shape[1]

        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(flat_size, 512), nn.ReLU(), nn.Dropout(0.4),
            nn.Linear(512, num_classes),
        )


    def forward(self, x):
        x = self.features(x)
        return self.classifier(x)

# %%
# loop for hyperparameter tuning
def train_model(lr, batch_size, epochs=10, weight_decay=0.0, use_scheduler=True):
    train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True, num_workers=0, pin_memory=True)
    val_loader = DataLoader(val_data, batch_size=batch_size, shuffle=False, num_workers=0, pin_memory=True)

    net = NeuralNet().to(device)
    loss_function = nn.CrossEntropyLoss()
    optimizer = optim.SGD(net.parameters(), lr=lr, momentum=0.9, weight_decay=weight_decay)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=2) if use_scheduler else None

    history = {'train_loss': [], 'val_loss': [], 'val_accuracy': []} # store training history

    for epoch in range(epochs):
        net.train()
        print(f'Training epoch {epoch}...')
        running_loss = 0.0
    
        for inputs, labels in train_loader:
    
            inputs = inputs.to(device, non_blocking=True)
            labels = labels.to(device, non_blocking=True)
    
            optimizer.zero_grad()
    
            outputs = net(inputs)
    
            loss = loss_function(outputs, labels)
            loss.backward() # backward propagation
            optimizer.step()
    
            running_loss += loss.item()
    
        history['train_loss'].append(running_loss / len(train_loader))
    
        print(f'Loss: {running_loss / len(train_loader):.4f}')
    
        # validation
        net.eval()
        val_loss = 0.0
        val_correct = 0
        val_total = 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = net(inputs)
                loss = loss_function(outputs, labels)
                val_loss += loss.item()
                _, predicted = torch.max(outputs, 1)
                val_total += labels.size(0)
                val_correct += (predicted == labels).sum().item()
    
        avg_val_loss = val_loss / len(val_loader)
        history['val_loss'].append(avg_val_loss)
        history['val_accuracy'].append(100 * val_correct / val_total)
    
        print(f'Val Loss: {val_loss/len(val_loader):.4f}, Val Accuracy: {100*val_correct/val_total:.2f}%')

        if scheduler:
            scheduler.step(avg_val_loss)

    return net, history

# %%
import time

results = {}

settings = [
    {'lr': 0.001, 'batch_size': 128, 'epochs': 15, 'weight_decay': 0.0, 'use_scheduler': True},
    {'lr': 0.002, 'batch_size': 128, 'epochs': 15, 'weight_decay': 0.0, 'use_scheduler': True},
    {'lr': 0.001, 'batch_size': 256, 'epochs': 15, 'weight_decay': 0.0, 'use_scheduler': True},
    {'lr': 0.002, 'batch_size': 256, 'epochs': 15, 'weight_decay': 0.0, 'use_scheduler': True},
    {'lr': 0.003, 'batch_size': 256, 'epochs': 15, 'weight_decay': 0.0, 'use_scheduler': True},
]

best_val_acc = 0
best_model_state = None

for i, setting in enumerate(settings):
    name = f"cfg{i}: lr={setting['lr']}, bs={setting['batch_size']}, wd={setting['weight_decay']}"
    print(f"Training with settings: {name}")

    start = time.time()
    net, history = train_model(**setting)
    elapsed = time.time() - start

    history['train_time'] = elapsed
    results[name] = history
    print(f"Training completed in {elapsed/60:.2f} min.")

    config_best_acc = max(history['val_accuracy'])
    if config_best_acc > best_val_acc:
        best_val_acc = config_best_acc
        best_model_state = net.state_dict()
        print(f"  New best overall: {best_val_acc:.2f}% ({name})")

torch.save(best_model_state, 'kanji_model.pth')
# Out:
# Training with settings: cfg0: lr=0.001, bs=128, wd=0.0
# Training epoch 0...
# Loss: 7.9392
# Val Loss: 7.4396, Val Accuracy: 0.94%
# Training epoch 1...
# Loss: 4.8480
# Val Loss: 1.0448, Val Accuracy: 83.00%
# Training epoch 2...
# Loss: 1.0177
# Val Loss: 0.3288, Val Accuracy: 93.61%
# Training epoch 3...
# Loss: 0.3981
# Val Loss: 0.1123, Val Accuracy: 97.71%
# Training epoch 4...
# Loss: 0.2421
# Val Loss: 0.0843, Val Accuracy: 98.19%
# Training epoch 5...
# Loss: 0.1727
# Val Loss: 0.0781, Val Accuracy: 98.28%
# Training epoch 6...
# Loss: 0.1350
# Val Loss: 0.0580, Val Accuracy: 98.70%
# Training epoch 7...
# Loss: 0.1096
# Val Loss: 0.0713, Val Accuracy: 98.35%
# Training epoch 8...
# Loss: 0.0919
# Val Loss: 0.0443, Val Accuracy: 98.97%
# Training epoch 9...
# Loss: 0.0788
# Val Loss: 0.0547, Val Accuracy: 98.64%
# Training epoch 10...
# Loss: 0.0688
# Val Loss: 0.0411, Val Accuracy: 99.00%
# Training epoch 11...
# Loss: 0.0613
# Val Loss: 0.0390, Val Accuracy: 99.06%
# Training epoch 12...
# Loss: 0.0548
# Val Loss: 0.0350, Val Accuracy: 99.20%
# Training epoch 13...
# Loss: 0.0496
# Val Loss: 0.0761, Val Accuracy: 97.96%
# Training epoch 14...
# Loss: 0.0455
# Val Loss: 0.0287, Val Accuracy: 99.31%
# Training completed in 15.49 min.
#   New best overall: 99.31% (cfg0: lr=0.001, bs=128, wd=0.0)
# Training with settings: cfg1: lr=0.002, bs=128, wd=0.0
# Training epoch 0...
# Loss: 7.9047
# Val Loss: 7.1528, Val Accuracy: 0.72%
# Training epoch 1...
# Loss: 3.9008
# Val Loss: 0.5772, Val Accuracy: 87.50%
# Training epoch 2...
# Loss: 0.5469
# Val Loss: 1.4991, Val Accuracy: 63.72%
# Training epoch 3...
# Loss: 0.2348
# Val Loss: 0.1067, Val Accuracy: 97.62%
# Training epoch 4...
# Loss: 0.1506
# Val Loss: 0.0811, Val Accuracy: 98.03%
# Training epoch 5...
# Loss: 0.1100
# Val Loss: 0.0522, Val Accuracy: 98.76%
# Training epoch 6...
# Loss: 0.0868
# Val Loss: 0.0446, Val Accuracy: 98.87%
# Training epoch 7...
# Loss: 0.0709
# Val Loss: 0.0315, Val Accuracy: 99.24%
# Training epoch 8...
# Loss: 0.0603
# Val Loss: 0.0491, Val Accuracy: 98.69%
# Training epoch 9...
# Loss: 0.0520
# Val Loss: 0.0308, Val Accuracy: 99.25%
# Training epoch 10...
# Loss: 0.0455
# Val Loss: 0.1437, Val Accuracy: 96.20%
# Training epoch 11...
# Loss: 0.0399
# Val Loss: 0.0467, Val Accuracy: 98.74%
# Training epoch 12...
# Loss: 0.0370
# Val Loss: 0.1628, Val Accuracy: 95.43%
# Training epoch 13...
# Loss: 0.0266
# Val Loss: 0.0213, Val Accuracy: 99.50%
# Training epoch 14...
# Loss: 0.0246
# Val Loss: 0.0222, Val Accuracy: 99.48%
# Training completed in 15.46 min.
#   New best overall: 99.50% (cfg1: lr=0.002, bs=128, wd=0.0)
# Training with settings: cfg2: lr=0.001, bs=256, wd=0.0
# Training epoch 0...
# Loss: 7.9812
# Val Loss: 7.7959, Val Accuracy: 0.27%
# Training epoch 1...
# Loss: 6.8938
# Val Loss: 4.7468, Val Accuracy: 26.59%
# Training epoch 2...
# Loss: 3.4569
# Val Loss: 2.3928, Val Accuracy: 52.18%
# Training epoch 3...
# Loss: 1.2850
# Val Loss: 0.9055, Val Accuracy: 81.65%
# Training epoch 4...
# Loss: 0.6441
# Val Loss: 0.2088, Val Accuracy: 96.03%
# Training epoch 5...
# Loss: 0.4129
# Val Loss: 0.1404, Val Accuracy: 97.20%
# Training epoch 6...
# Loss: 0.2988
# Val Loss: 0.1105, Val Accuracy: 97.64%
# Training epoch 7...
# Loss: 0.2326
# Val Loss: 0.1414, Val Accuracy: 97.01%
# Training epoch 8...
# Loss: 0.1904
# Val Loss: 0.0932, Val Accuracy: 98.11%
# Training epoch 9...
# Loss: 0.1616
# Val Loss: 4.3089, Val Accuracy: 29.06%
# Training epoch 10...
# Loss: 0.1394
# Val Loss: 0.1832, Val Accuracy: 95.68%
# Training epoch 11...
# Loss: 0.1232
# Val Loss: 0.1817, Val Accuracy: 95.39%
# Training epoch 12...
# Loss: 0.1054
# Val Loss: 0.0453, Val Accuracy: 99.01%
# Training epoch 13...
# Loss: 0.0982
# Val Loss: 0.0705, Val Accuracy: 98.38%
# Training epoch 14...
# Loss: 0.0925
# Val Loss: 0.0425, Val Accuracy: 99.06%
# Training completed in 15.40 min.
# Training with settings: cfg3: lr=0.002, bs=256, wd=0.0
# Training epoch 0...
# Loss: 7.8452
# Val Loss: 6.8327, Val Accuracy: 1.75%
# Training epoch 1...
# Loss: 4.3286
# Val Loss: 0.9605, Val Accuracy: 83.56%
# Training epoch 2...
# Loss: 0.9285
# Val Loss: 3.6701, Val Accuracy: 29.57%
# Training epoch 3...
# Loss: 0.3808
# Val Loss: 0.1303, Val Accuracy: 97.20%
# Training epoch 4...
# Loss: 0.2333
# Val Loss: 0.1031, Val Accuracy: 97.64%
# Training epoch 5...
# Loss: 0.1706
# Val Loss: 0.2871, Val Accuracy: 92.62%
# Training epoch 6...
# Loss: 0.1324
# Val Loss: 0.0671, Val Accuracy: 98.42%
# Training epoch 7...
# Loss: 0.1072
# Val Loss: 0.0477, Val Accuracy: 98.85%
# Training epoch 8...
# Loss: 0.0903
# Val Loss: 0.0539, Val Accuracy: 98.74%
# Training epoch 9...
# Loss: 0.0776
# Val Loss: 0.0623, Val Accuracy: 98.45%
# Training epoch 10...
# Loss: 0.0684
# Val Loss: 0.0350, Val Accuracy: 99.20%
# Training epoch 11...
# Loss: 0.0620
# Val Loss: 0.0314, Val Accuracy: 99.28%
# Training epoch 12...
# Loss: 0.0547
# Val Loss: 0.0299, Val Accuracy: 99.27%
# Training epoch 13...
# Loss: 0.0499
# Val Loss: 0.0548, Val Accuracy: 98.60%
# Training epoch 14...
# Loss: 0.0455
# Val Loss: 0.0462, Val Accuracy: 98.84%
# Training completed in 15.42 min.
# Training with settings: cfg4: lr=0.003, bs=256, wd=0.0
# Training epoch 0...
# Loss: 7.9439
# Val Loss: 7.3788, Val Accuracy: 0.37%
# Training epoch 1...
# Loss: 5.0356
# Val Loss: 1.0279, Val Accuracy: 80.64%
# Training epoch 2...
# Loss: 0.8911
# Val Loss: 0.2771, Val Accuracy: 93.69%
# Training epoch 3...
# Loss: 0.3205
# Val Loss: 0.1620, Val Accuracy: 96.39%
# Training epoch 4...
# Loss: 0.1951
# Val Loss: 0.0773, Val Accuracy: 98.17%
# Training epoch 5...
# Loss: 0.1410
# Val Loss: 2.7382, Val Accuracy: 45.33%
# Training epoch 6...
# Loss: 0.1106
# Val Loss: 2.1681, Val Accuracy: 57.23%
# Training epoch 7...
# Loss: 0.0894
# Val Loss: 0.0503, Val Accuracy: 98.76%
# Training epoch 8...
# Loss: 0.0755
# Val Loss: 0.0408, Val Accuracy: 99.00%
# Training epoch 9...
# Loss: 0.0648
# Val Loss: 0.0440, Val Accuracy: 98.87%
# Training epoch 10...
# Loss: 0.0565
# Val Loss: 0.0716, Val Accuracy: 98.20%
# Training epoch 11...
# Loss: 0.0500
# Val Loss: 0.0584, Val Accuracy: 98.45%
# Training epoch 12...
# Loss: 0.0390
# Val Loss: 0.0305, Val Accuracy: 99.28%
# Training epoch 13...
# Loss: 0.0354
# Val Loss: 0.0241, Val Accuracy: 99.44%
# Training epoch 14...
# Loss: 0.0331
# Val Loss: 0.0233, Val Accuracy: 99.44%
# Training completed in 15.39 min.

# %%
# plot
import matplotlib.pyplot as plt

for setting, history in results.items():
    train_losses = history['train_loss']
    val_losses = history['val_loss']
    val_accuracies = history['val_accuracy']

    fig, ax1 = plt.subplots(figsize=(10, 5))
    ax1.plot(train_losses, label='Train Loss', color='tab:blue')
    ax1.plot(val_losses, label='Val Loss', color='tab:orange')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Loss')
    ax1.legend(loc='upper left')

    ax2 = ax1.twinx()
    ax2.plot(val_accuracies, label='Val Accuracy', color='tab:green', linestyle='--')
    ax2.set_ylabel('Accuracy (%)')
    ax2.legend(loc='upper right')

    plt.title(f'Training Progress\n{setting}')
    plt.show()

# %%
net = NeuralNet().to(device)
net.load_state_dict(torch.load('kanji_model.pth', map_location=device))
# Out:
# <All keys matched successfully>

# %%
# eval on test data
test_loader = DataLoader(test_data, batch_size=128, shuffle=False, num_workers=0, pin_memory=True)
correct = 0
total = 0

net.eval()

# feed data in to get predictions and compare to labels
with torch.no_grad():
    for data in test_loader:
        images, labels = data
        images = images.to(device)
        labels = labels.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

accuracy = 100 * correct / total

print(f'Accuracy: {accuracy}%')
# Out:
# Accuracy: 99.50757575757575%
